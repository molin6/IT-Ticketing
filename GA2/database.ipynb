# %% [markdown]
# ## This class will hold the database creation and population work
#
# #### Install sqlalchemy_utils and Faker if they aren't already installed:

# %%
import importlib
import subprocess
import sys

def install_package(package_name: str):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])

packages = ['sqlalchemy_utils', 'Faker']

for package in packages:
    try:
        importlib.import_module(package)
        print(f"{package} is already installed.")
    except ModuleNotFoundError:
        print(f"{package} not found. Installing...")
        install_package(package)
        print(f"{package} has been installed.")
# Out:
# sqlalchemy_utils is already installed.
# Faker not found. Installing...
# Faker has been installed.

# %% [markdown]
# #### Create the database:

# %%
import sqlite3
import sqlalchemy
from sqlalchemy import create_engine, text
from sqlalchemy_utils import database_exists, create_database

engine = create_engine('sqlite:///it_ticketing_system.db', echo=True)
if not database_exists(engine.url):
    create_database(engine.url)

if sqlalchemy.__version__ < '2.0.0':
    raise ValueError('Please upgrade your version of SQLAlchemy to 2.0.0 or greater')

# %% [markdown]
# ### Using sqlite3 to drop tables if they're already created.

# %%
import sqlite3
db_file = 'it_ticketing_system.db'
cnn = sqlite3.connect(db_file)
cur = cnn.cursor()

table_names = []
results = cur.execute("SELECT tbl_name FROM sqlite_master")
for table_name in results:
    table_names.append(table_name[0])

for table_name in table_names:
    cur.execute(f'DROP TABLE IF EXISTS {table_name}')
    print(f'Dropped table \'{table_name}\'')

cnn.close()
# Out:
# Dropped table 'dim_organizations'
# Dropped table 'dim_departments'
# Dropped table 'dim_users'
# Dropped table 'dim_technicians'
# Dropped table 'fact_tickets'
# Dropped table 'fact_ticket_lines'

# %% [markdown]
# #### Create the tables for the database:

# %%
from sqlalchemy import Column, String, DateTime, Integer, ForeignKey
from sqlalchemy.orm import Session, DeclarativeBase, relationship
from sqlalchemy import select

class Base(DeclarativeBase):
    pass

class Organization(Base):
    __tablename__ = 'dim_organizations'
    
    organization_id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String, nullable=False)
    phone_number = Column(String)
    email_address = Column(String, nullable=False)
    state = Column(String, nullable=False)
    city = Column(String, nullable=False)
    zip_code = Column(Integer, nullable=False)
    street_address = Column(String, nullable=False)
    
    # Relationships
    users = relationship('User', back_populates='organization')
    departments = relationship('Department', back_populates='organization')

    def __repr__(self):
        return f'Organization(id={self.organization_id}, Name={self.name}, city={self.city}, state={self.state})'


class Department(Base):
    __tablename__ = 'dim_departments'
    
    department_id = Column(Integer, primary_key=True, autoincrement=True)
    organization_id = Column(Integer, ForeignKey('dim_organizations.organization_id'))
    name = Column(String, nullable=False)
    phone_number = Column(String)
    email_address = Column(String, nullable=False)
    
    # Relationships
    users = relationship('User', back_populates='department')
    organization = relationship('Organization', back_populates='departments')

    def __repr__(self):
        return f'Department(id={self.department_id}, Name={self.name}, Organization={self.organization.name})'


class User(Base):
    __tablename__ = 'dim_users'
    
    user_id = Column(Integer, primary_key=True, autoincrement=True)
    organization_id = Column(Integer, ForeignKey('dim_organizations.organization_id'))
    department_id = Column(Integer, ForeignKey('dim_departments.department_id'))
    last_name = Column(String, nullable=False)
    first_name = Column(String, nullable=False)
    phone_number = Column(String)
    email_address = Column(String, nullable=False)
    title = Column(String)
    
    # Relationships
    tickets = relationship('Ticket', back_populates='user')
    ticket_lines = relationship('TicketLine', back_populates='technician')
    technician_details = relationship('Technician', uselist=False, back_populates='user')
    organization = relationship('Organization', back_populates='users')
    department = relationship('Department', back_populates='users')


class Technician(Base):
    __tablename__ = 'dim_technicians'
    
    technician_id = Column(Integer, primary_key=True, autoincrement=True)
    user_id = Column(Integer, ForeignKey('dim_users.user_id'))
    manager_id = Column(Integer)
    
    # Relationships
    user = relationship('User', back_populates='technician_details')


class Ticket(Base):
    __tablename__ = 'fact_tickets'
    
    ticket_id = Column(Integer, primary_key=True, autoincrement=True)
    user_id = Column(Integer, ForeignKey('dim_users.user_id'))
    department_id = Column(Integer, ForeignKey('dim_departments.department_id'))
    prior_ticket_id = Column(Integer)
    ticket_category = Column(String, nullable=False)
    open_date_time = Column(DateTime, nullable=False)
    close_date_time = Column(DateTime)
    status = Column(String)
    description = Column(String, nullable=False)
    subject = Column(String, nullable=False)
    
    # Relationships
    user = relationship('User', back_populates='tickets')
    ticket_lines = relationship('TicketLine', back_populates='ticket')


class TicketLine(Base):
    __tablename__ = 'fact_ticket_lines'
    
    ticket_line_id = Column(Integer, primary_key=True, autoincrement=True)
    ticket_id = Column(Integer, ForeignKey('fact_tickets.ticket_id'))
    technician_id = Column(Integer, ForeignKey('dim_users.user_id'))
    assignment_date_time = Column(DateTime, nullable=False)
    completion_date_time = Column(DateTime)
    notes = Column(String)
    
    # Relationships
    technician = relationship('User', back_populates='ticket_lines')
    ticket = relationship('Ticket', back_populates='ticket_lines')

Base.metadata.create_all(engine)

# %% [markdown]
# #### Initial Database Definitions:

# %%
db_file = 'it_ticketing_system.db'
cnn = sqlite3.connect(db_file)
cur = cnn.cursor()
tables = cur.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()

def bool_to_yes_no(value):
    if value == 0:
        return 'NO'
    elif value == 1:
        return 'YES'

for table in tables:
    print('------------------')
    print('Table Name: ' + table[0])
    print('------------------')
    columns = cur.execute(f'PRAGMA table_info(\'%s\');' % table[0]).fetchall()
    for column in columns:
        col_id, col_name, col_type, col_notnull, col_default, col_pk = column
        print(f"  Column: {col_name}")
        print(f"    Type: {col_type}")
        print(f"    Not Null: {bool_to_yes_no(col_notnull)}")
        print(f"    Default Value: {col_default}")
        print(f"    Primary Key: {bool_to_yes_no(col_pk)}")

cnn.close()

# %% [markdown]
# #### Creating method to add be able to pass a List[Object] and have them added to the database, where Object is the table in ORM form

# %%
from sqlalchemy.orm import Session
from sqlalchemy.exc import SQLAlchemyError

def add_objects_to_db(session: Session, objects: list):
    try:
        session.add_all(objects)
        session.commit()
        return True
    except SQLAlchemyError as e:
        print(f"An error occurred: {e}")
        session.rollback()
        return False

# %% [markdown]
# #### Seed the tables:

# %%
from sqlalchemy.orm import Session
from faker import Faker
import random

fake = Faker()

def seed_organizations(session: Session, num_organizations: int):
    organizations = []
    for _ in range(num_organizations):
        organization = Organization(
            name=fake.company(),
            phone_number=fake.phone_number(),
            email_address=fake.company_email(),
            state=fake.state_abbr(),
            city=fake.city(),
            zip_code=fake.zipcode(),
            street_address=fake.street_address(),
        )
        organizations.append(organization)
    return add_objects_to_db(session, organizations)

def seed_departments(session: Session, num_departments_per_organization: int, organizations: list):
    departments = []
    for organization in organizations:
        for _ in range(num_departments_per_organization):
            department = Department(
                organization_id=organization.organization_id,
                name=fake.bs(),
                phone_number=fake.phone_number(),
                email_address=fake.company_email(),
            )
            departments.append(department)
    return add_objects_to_db(session, departments)

def seed_users(session: Session, num_users_per_department: int, departments: list):
    users = []
    for department in departments:
        for _ in range(num_users_per_department):
            user = User(
                organization_id=department.organization_id,
                department_id=department.department_id,
                last_name=fake.last_name(),
                first_name=fake.first_name(),
                phone_number=fake.phone_number(),
                email_address=fake.email(),
                title=fake.job(),
            )
            users.append(user)
    return add_objects_to_db(session, users)

def seed_tickets(session: Session, num_tickets_per_user: int, users: list):
    tickets = []
    for user in users:
        for _ in range(num_tickets_per_user):
            ticket = Ticket(
                user_id=user.user_id,
                department_id=user.department_id,
                ticket_category=fake.word(),
                open_date_time=fake.date_time_this_decade(),
                close_date_time=fake.date_time_this_decade(),
                status=fake.word(),
                description=fake.text(),
                subject=fake.sentence(),
            )
            tickets.append(ticket)
    return add_objects_to_db(session, tickets)

def seed_technicians(session: Session, users: list, num_technicians: int):
    technicians = []
    selected_users = random.sample(users, k=min(num_technicians, len(users)))

    for user in selected_users:
        technician = Technician(user_id=user.user_id)
        technicians.append(technician)

    return add_objects_to_db(session, technicians)

def seed_ticket_lines(session: Session, num_ticket_lines_per_ticket: int, tickets: list, technicians: list):
    ticket_lines = []
    for ticket in tickets:
        for _ in range(num_ticket_lines_per_ticket):
            technician = random.choice(technicians)

            ticket_line = TicketLine(
                ticket_id=ticket.ticket_id,
                technician_id=technician.technician_id,
                assignment_date_time=fake.date_time_this_decade(),
                completion_date_time=fake.date_time_this_decade(),
                notes=fake.text(),
            )
            ticket_lines.append(ticket_line)
    return add_objects_to_db(session, ticket_lines)

session = Session(engine)

#Create the organizations:
num_organizations = 5
seed_organizations(session, num_organizations)
organizations = session.query(Organization).all()

#Create the departments:
num_departments_per_organization = 3
seed_departments(session, num_departments_per_organization, organizations)
departments = session.query(Department).all()

#Create the users:
num_users_per_department = 10
seed_users(session, 10, departments)
users = session.query(User).all()

#Create the tickets:
num_tickets_per_user = 5
seed_tickets(session, num_tickets_per_user, users)
tickets = session.query(Ticket).all()

#Create the technicians:
num_technicians = 3
seed_technicians(session, users, num_technicians)
technicians = session.query(Technician).all()

#Create the ticket lines:
num_ticket_lines_per_ticket = 3
seed_ticket_lines(session, num_ticket_lines_per_ticket, tickets, technicians)
ticketlines = session.query(TicketLine).all()
# Out:
# 2023-09-30 21:09:37,166 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-30 21:09:37,168 INFO sqlalchemy.engine.Engine INSERT INTO dim_organizations (name, phone_number, email_address, state, city, zip_code, street_address) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING organization_id
# 2023-09-30 21:09:37,169 INFO sqlalchemy.engine.Engine [generated in 0.00016s (insertmanyvalues) 1/5 (ordered; batch not supported)] ('Jennings-Gonzalez', '556-446-8262', 'scott17@decker.com', 'WA', 'Port Michaeltown', '27915', '2102 Kyle Ranch')
# 2023-09-30 21:09:37,177 INFO sqlalchemy.engine.Engine INSERT INTO dim_organizations (name, phone_number, email_address, state, city, zip_code, street_address) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING organization_id
# 2023-09-30 21:09:37,178 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/5 (ordered; batch not supported)] ('Mckee and Sons', '001-279-281-4374x8917', 'tapiacarl@collins.biz', 'WY', 'Lutzborough', '38014', '889 Marshall Run Suite 769')
# 2023-09-30 21:09:37,179 INFO sqlalchemy.engine.Engine INSERT INTO dim_organizations (name, phone_number, email_address, state, city, zip_code, street_address) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING organization_id
# 2023-09-30 21:09:37,180 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/5 (ordered; batch not supported)] ('Floyd, House and Morrison', '907-551-7720', 'georgelewis@davis-tucker.biz', 'MD', 'Port Juanhaven', '37982', '055 Heidi Plains')
# 2023-09-30 21:09:37,180 INFO sqlalchemy.engine.Engine INSERT INTO dim_organizations (name, phone_number, email_address, state, city, zip_code, street_address) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING organization_id
# 2023-09-30 21:09:37,181 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/5 (ordered; batch not supported)] ('Todd-Campbell', '+1-658-967-3996', 'danielwest@campbell.info', 'MS', 'East Scott', '70157', '39307 Tina Points Apt. 364')
# 2023-09-30 21:09:37,181 INFO sqlalchemy.engine.Engine INSERT INTO dim_organizations (name, phone_number, email_address, state, city, zip_code, street_address) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING organization_id
# 2023-09-30 21:09:37,182 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/5 (ordered; batch not supported)] ('Richard PLC', '7643580103', 'ndavis@hudson.biz', 'OR', 'West Edward', '62808', '858 Erickson Pines')
# 2023-09-30 21:09:37,184 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-30 21:09:37,190 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-30 21:09:37,192 INFO sqlalchemy.engine.Engine SELECT dim_organizations.organization_id AS dim_organizations_organization_id, dim_organizations.name AS dim_organizations_name, dim_organizations.phone_number AS dim_organizations_phone_number, dim_organizations.email_address AS dim_organizations_email_address, dim_organizations.state AS dim_organizations_state, dim_organizations.city AS dim_organizations_city, dim_organizations.zip_code AS dim_organizations_zip_code, dim_organizations.street_address AS dim_organizations_street_address
# FROM dim_organizations
# 2023-09-30 21:09:37,192 INFO sqlalchemy.engine.Engine [generated in 0.00050s] ()
# 2023-09-30 21:09:37,202 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,202 INFO sqlalchemy.engine.Engine [generated in 0.00013s (insertmanyvalues) 1/15 (ordered; batch not supported)] (1, 'utilize wireless users', '001-868-624-9683x0213', 'misty22@dodson.com')
# 2023-09-30 21:09:37,205 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,206 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/15 (ordered; batch not supported)] (1, 'whiteboard intuitive supply-chains', '+1-632-959-5553x6291', 'fhubbard@flowers.com')
# 2023-09-30 21:09:37,207 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,208 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/15 (ordered; batch not supported)] (1, 'embrace scalable eyeballs', '+1-957-580-1554x09143', 'daniel11@moore.com')
# 2023-09-30 21:09:37,209 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,210 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/15 (ordered; batch not supported)] (2, 'reinvent bleeding-edge synergies', '996-895-0585', 'matthew11@hill.com')
# 2023-09-30 21:09:37,211 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,211 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/15 (ordered; batch not supported)] (2, 'evolve ubiquitous systems', '(775)932-1321x5065', 'billy98@melendez.info')
# 2023-09-30 21:09:37,212 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,212 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/15 (ordered; batch not supported)] (2, 'harness revolutionary portals', '430-896-1381', 'ahunt@nixon.com')
# 2023-09-30 21:09:37,213 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,213 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/15 (ordered; batch not supported)] (3, 'strategize rich partnerships', '001-383-359-7772', 'sullivanmelinda@hernandez.biz')
# 2023-09-30 21:09:37,213 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,214 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/15 (ordered; batch not supported)] (3, 'cultivate open-source action-items', '722-294-4579x0823', 'anthonyorr@west.com')
# 2023-09-30 21:09:37,215 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,215 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/15 (ordered; batch not supported)] (3, 're-contextualize B2B platforms', '810-637-0397x00672', 'gwagner@austin.info')
# 2023-09-30 21:09:37,216 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,217 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/15 (ordered; batch not supported)] (4, 'transition leading-edge applications', '491-434-8092', 'michael35@morgan.com')
# 2023-09-30 21:09:37,217 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,218 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/15 (ordered; batch not supported)] (4, 'monetize extensible paradigms', '842-661-8565x870', 'samuel57@harris.org')
# 2023-09-30 21:09:37,220 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,220 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/15 (ordered; batch not supported)] (4, 'expedite intuitive experiences', '001-337-668-4917x35174', 'kimberlymiller@johnson.com')
# 2023-09-30 21:09:37,221 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,221 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/15 (ordered; batch not supported)] (5, 'orchestrate distributed applications', '6742642820', 'adennis@steele.com')
# 2023-09-30 21:09:37,222 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,223 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/15 (ordered; batch not supported)] (5, 'facilitate enterprise technologies', '+1-871-874-4250x580', 'racheljackson@silva.biz')
# 2023-09-30 21:09:37,224 INFO sqlalchemy.engine.Engine INSERT INTO dim_departments (organization_id, name, phone_number, email_address) VALUES (?, ?, ?, ?) RETURNING department_id
# 2023-09-30 21:09:37,225 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/15 (ordered; batch not supported)] (5, 'transform best-of-breed portals', '7079516489', 'jenna15@huber-thomas.biz')
# 2023-09-30 21:09:37,227 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-30 21:09:37,233 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-30 21:09:37,236 INFO sqlalchemy.engine.Engine SELECT dim_departments.department_id AS dim_departments_department_id, dim_departments.organization_id AS dim_departments_organization_id, dim_departments.name AS dim_departments_name, dim_departments.phone_number AS dim_departments_phone_number, dim_departments.email_address AS dim_departments_email_address
# FROM dim_departments
# 2023-09-30 21:09:37,238 INFO sqlalchemy.engine.Engine [generated in 0.00148s] ()
# 2023-09-30 21:09:37,279 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,280 INFO sqlalchemy.engine.Engine [generated in 0.00039s (insertmanyvalues) 1/150 (ordered; batch not supported)] (1, 1, 'Watson', 'Richard', '+1-611-388-2633x267', 'brittanyking@example.org', 'Statistician')
# 2023-09-30 21:09:37,282 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,282 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/150 (ordered; batch not supported)] (1, 1, 'Mclaughlin', 'Brandon', '278-993-4165x9583', 'xjoseph@example.com', 'Printmaker')
# 2023-09-30 21:09:37,283 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,283 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/150 (ordered; batch not supported)] (1, 1, 'Marshall', 'Bobby', '4837566579', 'bailey41@example.com', 'Editor, commissioning')
# 2023-09-30 21:09:37,284 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,285 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/150 (ordered; batch not supported)] (1, 1, 'Harris', 'Chelsea', '(428)524-9147', 'framos@example.net', 'Scientist, product/process development')
# 2023-09-30 21:09:37,286 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,287 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/150 (ordered; batch not supported)] (1, 1, 'Charles', 'Jason', '(301)678-6664x901', 'ryanrocha@example.com', 'Science writer')
# 2023-09-30 21:09:37,288 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,289 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/150 (ordered; batch not supported)] (1, 1, 'Myers', 'Robert', '+1-302-728-4601x31841', 'obowers@example.net', 'Hotel manager')
# 2023-09-30 21:09:37,289 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,290 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/150 (ordered; batch not supported)] (1, 1, 'Perez', 'Scott', '846-503-3768', 'michael44@example.net', 'Sport and exercise psychologist')
# 2023-09-30 21:09:37,290 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,291 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/150 (ordered; batch not supported)] (1, 1, 'Young', 'Jessica', '(864)398-0335', 'mdavis@example.org', 'Social research officer, government')
# 2023-09-30 21:09:37,291 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,292 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/150 (ordered; batch not supported)] (1, 1, 'Reese', 'James', '(633)818-3915x16038', 'smithjoshua@example.com', 'Television floor manager')
# 2023-09-30 21:09:37,293 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,293 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/150 (ordered; batch not supported)] (1, 1, 'Roberts', 'Andrea', '+1-846-949-4016', 'brooke64@example.com', 'Sport and exercise psychologist')
# 2023-09-30 21:09:37,293 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,294 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/150 (ordered; batch not supported)] (1, 2, 'Jackson', 'Cathy', '(732)829-8931x6599', 'jeffrey80@example.com', 'Writer')
# 2023-09-30 21:09:37,295 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,296 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/150 (ordered; batch not supported)] (1, 2, 'Dennis', 'Amber', '001-588-466-7126x101', 'twagner@example.net', 'Surveyor, insurance')
# 2023-09-30 21:09:37,296 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,296 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/150 (ordered; batch not supported)] (1, 2, 'Richardson', 'Cheryl', '+1-555-791-9549x0615', 'brandon80@example.net', 'Dance movement psychotherapist')
# 2023-09-30 21:09:37,297 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,297 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/150 (ordered; batch not supported)] (1, 2, 'Reynolds', 'Jason', '001-555-223-6355x67311', 'jameshughes@example.com', 'Journalist, broadcasting')
# 2023-09-30 21:09:37,298 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,298 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/150 (ordered; batch not supported)] (1, 2, 'Lutz', 'Lisa', '(297)757-7021', 'ftate@example.net', 'Exhibitions officer, museum/gallery')
# 2023-09-30 21:09:37,299 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,300 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/150 (ordered; batch not supported)] (1, 2, 'Blankenship', 'Frederick', '669.502.6273x7924', 'elizabethstewart@example.org', 'Education officer, museum')
# 2023-09-30 21:09:37,301 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,302 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/150 (ordered; batch not supported)] (1, 2, 'Cline', 'Shari', '+1-546-322-9858x571', 'rperez@example.org', 'Furniture designer')
# 2023-09-30 21:09:37,303 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,305 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/150 (ordered; batch not supported)] (1, 2, 'Franklin', 'Arthur', '+1-530-439-6630x746', 'cgregory@example.net', 'Risk manager')
# 2023-09-30 21:09:37,306 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,307 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/150 (ordered; batch not supported)] (1, 2, 'Alexander', 'Melissa', '(502)920-4709x66239', 'lanceporter@example.org', 'Camera operator')
# 2023-09-30 21:09:37,308 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,309 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/150 (ordered; batch not supported)] (1, 2, 'Black', 'Olivia', '975.811.3746', 'reyesmonique@example.org', 'Planning and development surveyor')
# 2023-09-30 21:09:37,310 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,311 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/150 (ordered; batch not supported)] (1, 3, 'Robertson', 'Jason', '926-853-6952', 'melissaaguirre@example.net', 'Engineer, petroleum')
# 2023-09-30 21:09:37,311 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,312 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/150 (ordered; batch not supported)] (1, 3, 'Lopez', 'Timothy', '(275)573-6231x354', 'jasonstone@example.net', 'Radio broadcast assistant')
# 2023-09-30 21:09:37,313 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,313 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/150 (ordered; batch not supported)] (1, 3, 'Alvarez', 'Cory', '8976474566', 'cooleymichael@example.com', 'Product/process development scientist')
# 2023-09-30 21:09:37,314 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,314 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/150 (ordered; batch not supported)] (1, 3, 'Mitchell', 'Michelle', '(817)932-1160x616', 'williamhill@example.net', 'English as a second language teacher')
# 2023-09-30 21:09:37,316 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,316 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/150 (ordered; batch not supported)] (1, 3, 'Dennis', 'Isaac', '396-584-5784', 'george34@example.com', 'Financial risk analyst')
# 2023-09-30 21:09:37,317 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,318 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/150 (ordered; batch not supported)] (1, 3, 'Acosta', 'Joseph', '769-248-8587x43728', 'martinmckenzie@example.org', 'Town planner')
# 2023-09-30 21:09:37,319 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,320 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/150 (ordered; batch not supported)] (1, 3, 'Cannon', 'Christopher', '(329)946-5727x98352', 'rgarcia@example.net', 'Consulting civil engineer')
# 2023-09-30 21:09:37,320 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,321 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/150 (ordered; batch not supported)] (1, 3, 'Cooper', 'Charles', '710.468.4399x741', 'reevesadrian@example.net', 'Data processing manager')
# 2023-09-30 21:09:37,322 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,323 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/150 (ordered; batch not supported)] (1, 3, 'Kelly', 'Mark', '569.679.8602x746', 'haysfranklin@example.org', 'Magazine journalist')
# 2023-09-30 21:09:37,324 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,325 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/150 (ordered; batch not supported)] (1, 3, 'Payne', 'April', '+1-476-691-5973', 'patrick88@example.com', 'Engineer, control and instrumentation')
# 2023-09-30 21:09:37,326 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,327 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/150 (ordered; batch not supported)] (2, 4, 'Harris', 'John', '+1-498-570-6318x483', 'marissa88@example.com', 'Production assistant, radio')
# 2023-09-30 21:09:37,328 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,328 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/150 (ordered; batch not supported)] (2, 4, 'Webb', 'William', '458.806.1480x606', 'austin04@example.com', 'Insurance risk surveyor')
# 2023-09-30 21:09:37,329 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,330 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/150 (ordered; batch not supported)] (2, 4, 'Ryan', 'Ronald', '855-420-2619x35725', 'robert87@example.com', 'Contractor')
# 2023-09-30 21:09:37,330 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,331 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/150 (ordered; batch not supported)] (2, 4, 'Myers', 'Alexander', '001-804-466-0022x06023', 'chandleralan@example.net', 'Psychotherapist, child')
# 2023-09-30 21:09:37,331 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,331 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/150 (ordered; batch not supported)] (2, 4, 'Vasquez', 'April', '787-210-2556x37691', 'deborahcantu@example.net', 'Tour manager')
# 2023-09-30 21:09:37,332 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,333 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/150 (ordered; batch not supported)] (2, 4, 'Walker', 'Jose', '415-883-9750', 'jason98@example.org', 'Insurance risk surveyor')
# 2023-09-30 21:09:37,334 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,335 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/150 (ordered; batch not supported)] (2, 4, 'White', 'Ryan', '+1-264-766-7305x6314', 'smithjean@example.net', 'Dentist')
# 2023-09-30 21:09:37,336 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,337 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/150 (ordered; batch not supported)] (2, 4, 'Everett', 'Rebecca', '650.344.5645', 'mhayes@example.net', 'Therapist, nutritional')
# 2023-09-30 21:09:37,339 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,339 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/150 (ordered; batch not supported)] (2, 4, 'Singh', 'Jason', '981-273-5799x39828', 'ystrickland@example.com', 'Engineer, broadcasting (operations)')
# 2023-09-30 21:09:37,340 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,341 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/150 (ordered; batch not supported)] (2, 4, 'Jones', 'Alexandra', '462-337-9225x0929', 'jennifermayer@example.net', 'Community pharmacist')
# 2023-09-30 21:09:37,341 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,342 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/150 (ordered; batch not supported)] (2, 5, 'Wright', 'Carol', '604.929.5739', 'hleonard@example.org', 'Psychologist, counselling')
# 2023-09-30 21:09:37,342 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,343 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/150 (ordered; batch not supported)] (2, 5, 'Garcia', 'Joseph', '(401)820-1339x805', 'taylorwilliam@example.com', 'Designer, textile')
# 2023-09-30 21:09:37,343 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,343 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/150 (ordered; batch not supported)] (2, 5, 'Powers', 'Stephanie', '888-201-3965', 'jgomez@example.net', 'Production engineer')
# 2023-09-30 21:09:37,345 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,345 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/150 (ordered; batch not supported)] (2, 5, 'Bowers', 'Kim', '+1-622-579-3663', 'hayeskevin@example.org', 'Designer, multimedia')
# 2023-09-30 21:09:37,346 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,346 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/150 (ordered; batch not supported)] (2, 5, 'Haney', 'Kristin', '4047862145', 'leeangela@example.com', 'Fashion designer')
# 2023-09-30 21:09:37,347 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,347 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/150 (ordered; batch not supported)] (2, 5, 'English', 'Joseph', '239-382-8382x46569', 'lstewart@example.org', 'Software engineer')
# 2023-09-30 21:09:37,348 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,349 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/150 (ordered; batch not supported)] (2, 5, 'Johnson', 'Tiffany', '327-341-0744x0482', 'sanderseric@example.com', 'Therapist, sports')
# 2023-09-30 21:09:37,350 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,350 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/150 (ordered; batch not supported)] (2, 5, 'Cannon', 'Matthew', '767-716-0587x116', 'heather77@example.com', 'Naval architect')
# 2023-09-30 21:09:37,351 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,352 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/150 (ordered; batch not supported)] (2, 5, 'Morrow', 'Erica', '213-961-1539x5732', 'lnunez@example.net', 'Human resources officer')
# 2023-09-30 21:09:37,352 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,353 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/150 (ordered; batch not supported)] (2, 5, 'Perez', 'Anna', '(641)779-0155x66481', 'emckee@example.org', 'Chief of Staff')
# 2023-09-30 21:09:37,354 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,355 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/150 (ordered; batch not supported)] (2, 6, 'Parks', 'Mallory', '001-894-781-4451x7656', 'yramos@example.org', 'Private music teacher')
# 2023-09-30 21:09:37,356 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,357 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/150 (ordered; batch not supported)] (2, 6, 'Roberts', 'Krystal', '001-417-325-6225', 'michaelrodriguez@example.com', 'International aid/development worker')
# 2023-09-30 21:09:37,358 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,359 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/150 (ordered; batch not supported)] (2, 6, 'Blanchard', 'Shirley', '684.371.3468', 'stephanietownsend@example.net', 'Geochemist')
# 2023-09-30 21:09:37,360 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,360 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/150 (ordered; batch not supported)] (2, 6, 'Clark', 'Carlos', '001-243-258-1010x14750', 'rossjason@example.net', 'Lobbyist')
# 2023-09-30 21:09:37,361 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,361 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/150 (ordered; batch not supported)] (2, 6, 'Rojas', 'Kevin', '770-315-9878x41291', 'scott65@example.com', 'Paediatric nurse')
# 2023-09-30 21:09:37,362 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,363 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/150 (ordered; batch not supported)] (2, 6, 'Kim', 'Evan', '(288)841-4528x7641', 'ashleybuchanan@example.org', 'Adult guidance worker')
# 2023-09-30 21:09:37,363 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,363 INFO sqlalchemy.engine.Engine [insertmanyvalues 57/150 (ordered; batch not supported)] (2, 6, 'Sanchez', 'Mary', '(753)422-4610', 'catherine51@example.org', 'Architect')
# 2023-09-30 21:09:37,364 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,365 INFO sqlalchemy.engine.Engine [insertmanyvalues 58/150 (ordered; batch not supported)] (2, 6, 'Tanner', 'Daniel', '+1-639-558-3080x288', 'qparker@example.org', 'Teacher, music')
# 2023-09-30 21:09:37,365 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,366 INFO sqlalchemy.engine.Engine [insertmanyvalues 59/150 (ordered; batch not supported)] (2, 6, 'Hicks', 'Diane', '001-223-681-9144', 'ewalker@example.org', 'Ship broker')
# 2023-09-30 21:09:37,366 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,367 INFO sqlalchemy.engine.Engine [insertmanyvalues 60/150 (ordered; batch not supported)] (2, 6, 'Ross', 'Gerald', '(516)533-4841x773', 'kathyrichardson@example.net', 'Theatre stage manager')
# 2023-09-30 21:09:37,368 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,369 INFO sqlalchemy.engine.Engine [insertmanyvalues 61/150 (ordered; batch not supported)] (3, 7, 'Mercado', 'Cheryl', '001-755-529-6517x45685', 'dmitchell@example.org', 'Dance movement psychotherapist')
# 2023-09-30 21:09:37,371 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,372 INFO sqlalchemy.engine.Engine [insertmanyvalues 62/150 (ordered; batch not supported)] (3, 7, 'Moore', 'James', '+1-969-981-4024x209', 'gmcknight@example.com', 'Therapist, nutritional')
# 2023-09-30 21:09:37,372 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,373 INFO sqlalchemy.engine.Engine [insertmanyvalues 63/150 (ordered; batch not supported)] (3, 7, 'Martin', 'Parker', '441-948-4872', 'awilliams@example.org', 'Production manager')
# 2023-09-30 21:09:37,373 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,375 INFO sqlalchemy.engine.Engine [insertmanyvalues 64/150 (ordered; batch not supported)] (3, 7, 'Moreno', 'Elizabeth', '364.296.1376', 'teresa27@example.net', 'Scientist, research (maths)')
# 2023-09-30 21:09:37,375 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,376 INFO sqlalchemy.engine.Engine [insertmanyvalues 65/150 (ordered; batch not supported)] (3, 7, 'Chen', 'Juan', '001-581-878-7801x62798', 'wiserobert@example.com', 'Physicist, medical')
# 2023-09-30 21:09:37,377 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,378 INFO sqlalchemy.engine.Engine [insertmanyvalues 66/150 (ordered; batch not supported)] (3, 7, 'Kennedy', 'Timothy', '+1-862-217-1792x5665', 'jonesmarcus@example.com', 'Early years teacher')
# 2023-09-30 21:09:37,378 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,379 INFO sqlalchemy.engine.Engine [insertmanyvalues 67/150 (ordered; batch not supported)] (3, 7, 'Guzman', 'Taylor', '+1-528-499-6335x22379', 'munozcharles@example.com', 'Chief Operating Officer')
# 2023-09-30 21:09:37,379 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,380 INFO sqlalchemy.engine.Engine [insertmanyvalues 68/150 (ordered; batch not supported)] (3, 7, 'Jones', 'Lynn', '646.721.2237x9829', 'grantwatkins@example.org', 'Print production planner')
# 2023-09-30 21:09:37,380 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,381 INFO sqlalchemy.engine.Engine [insertmanyvalues 69/150 (ordered; batch not supported)] (3, 7, 'Atkinson', 'Erik', '+1-503-734-3020x80295', 'sarah46@example.org', 'Accommodation manager')
# 2023-09-30 21:09:37,381 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,382 INFO sqlalchemy.engine.Engine [insertmanyvalues 70/150 (ordered; batch not supported)] (3, 7, 'Esparza', 'Jose', '215-408-2732x166', 'garrettmargaret@example.net', 'Academic librarian')
# 2023-09-30 21:09:37,382 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,383 INFO sqlalchemy.engine.Engine [insertmanyvalues 71/150 (ordered; batch not supported)] (3, 8, 'Mitchell', 'Rachael', '929-943-5715x767', 'swebster@example.com', 'Physicist, medical')
# 2023-09-30 21:09:37,383 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,385 INFO sqlalchemy.engine.Engine [insertmanyvalues 72/150 (ordered; batch not supported)] (3, 8, 'Kelly', 'Corey', '865-997-9967x539', 'fletcherjennifer@example.net', 'Publishing rights manager')
# 2023-09-30 21:09:37,386 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,387 INFO sqlalchemy.engine.Engine [insertmanyvalues 73/150 (ordered; batch not supported)] (3, 8, 'Fletcher', 'Mercedes', '852.589.1611x688', 'cookmichaela@example.org', 'Conference centre manager')
# 2023-09-30 21:09:37,389 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,391 INFO sqlalchemy.engine.Engine [insertmanyvalues 74/150 (ordered; batch not supported)] (3, 8, 'Franklin', 'Mario', '552-975-0255x829', 'michael83@example.net', 'Commissioning editor')
# 2023-09-30 21:09:37,392 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,393 INFO sqlalchemy.engine.Engine [insertmanyvalues 75/150 (ordered; batch not supported)] (3, 8, 'Fisher', 'Donald', '289-463-9301x4064', 'michaelporter@example.net', 'Senior tax professional/tax inspector')
# 2023-09-30 21:09:37,393 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,395 INFO sqlalchemy.engine.Engine [insertmanyvalues 76/150 (ordered; batch not supported)] (3, 8, 'Alvarez', 'Brian', '+1-293-792-4265x741', 'caldwellrebecca@example.com', 'Production manager')
# 2023-09-30 21:09:37,396 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,397 INFO sqlalchemy.engine.Engine [insertmanyvalues 77/150 (ordered; batch not supported)] (3, 8, 'Martin', 'Heather', '+1-403-798-8289x89933', 'andrea22@example.org', 'Sport and exercise psychologist')
# 2023-09-30 21:09:37,398 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,399 INFO sqlalchemy.engine.Engine [insertmanyvalues 78/150 (ordered; batch not supported)] (3, 8, 'Hodges', 'Mary', '5252690753', 'ggates@example.net', 'Designer, television/film set')
# 2023-09-30 21:09:37,400 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,401 INFO sqlalchemy.engine.Engine [insertmanyvalues 79/150 (ordered; batch not supported)] (3, 8, 'Clark', 'Jeffrey', '409.560.3875', 'aviladustin@example.com', 'Network engineer')
# 2023-09-30 21:09:37,402 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,403 INFO sqlalchemy.engine.Engine [insertmanyvalues 80/150 (ordered; batch not supported)] (3, 8, 'Hudson', 'Steven', '+1-945-532-0931x529', 'ystewart@example.com', 'Insurance broker')
# 2023-09-30 21:09:37,403 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,405 INFO sqlalchemy.engine.Engine [insertmanyvalues 81/150 (ordered; batch not supported)] (3, 9, 'Murphy', 'Andrea', '416-884-6619x20240', 'carolyncarey@example.org', 'Engineer, drilling')
# 2023-09-30 21:09:37,405 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,406 INFO sqlalchemy.engine.Engine [insertmanyvalues 82/150 (ordered; batch not supported)] (3, 9, 'Lyons', 'Jonathan', '852.565.4053x60205', 'diazjose@example.com', 'Licensed conveyancer')
# 2023-09-30 21:09:37,407 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,408 INFO sqlalchemy.engine.Engine [insertmanyvalues 83/150 (ordered; batch not supported)] (3, 9, 'Webster', 'Mark', '001-588-837-0241x58341', 'williamtucker@example.com', 'Conference centre manager')
# 2023-09-30 21:09:37,409 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,409 INFO sqlalchemy.engine.Engine [insertmanyvalues 84/150 (ordered; batch not supported)] (3, 9, 'Skinner', 'Richard', '530-491-5454', 'milleradam@example.com', 'Surveyor, building control')
# 2023-09-30 21:09:37,410 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,411 INFO sqlalchemy.engine.Engine [insertmanyvalues 85/150 (ordered; batch not supported)] (3, 9, 'Cook', 'Michelle', '381-779-6730', 'zadams@example.org', 'Community pharmacist')
# 2023-09-30 21:09:37,412 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,412 INFO sqlalchemy.engine.Engine [insertmanyvalues 86/150 (ordered; batch not supported)] (3, 9, 'Green', 'David', '425.554.4416', 'hamiltonjane@example.org', 'Teacher, special educational needs')
# 2023-09-30 21:09:37,413 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,413 INFO sqlalchemy.engine.Engine [insertmanyvalues 87/150 (ordered; batch not supported)] (3, 9, 'Morales', 'Patrick', '001-543-842-6083x828', 'hannadiana@example.com', 'Production engineer')
# 2023-09-30 21:09:37,413 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,414 INFO sqlalchemy.engine.Engine [insertmanyvalues 88/150 (ordered; batch not supported)] (3, 9, 'Bowman', 'Paula', '7436578322', 'sarahramirez@example.net', 'Risk manager')
# 2023-09-30 21:09:37,414 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,415 INFO sqlalchemy.engine.Engine [insertmanyvalues 89/150 (ordered; batch not supported)] (3, 9, 'Cline', 'Thomas', '(852)468-1964', 'hannah58@example.org', 'Historic buildings inspector/conservation officer')
# 2023-09-30 21:09:37,416 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,416 INFO sqlalchemy.engine.Engine [insertmanyvalues 90/150 (ordered; batch not supported)] (3, 9, 'Gibson', 'Jennifer', '661.862.7123x27319', 'qmurphy@example.org', 'Agricultural consultant')
# 2023-09-30 21:09:37,417 INFO sqlalchemy.engine.Engine INSERT INTO dim_users (organization_id, department_id, last_name, first_name, phone_number, email_address, title) VALUES (?, ?, ?, ?, ?, ?, ?) RETURNING user_id
# 2023-09-30 21:09:37,417 INFO sqlalchemy.engine.Engine [insertmanyvalues 91/150 (ordered; batch not supported)] (4, 10, 'Franco', 'Raymond', '001-775-352-9435x66718', 'michaelmullins@example.com', 'Visual merchandiser')
# ...
# 2023-09-30 21:09:46,665 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,666 INFO sqlalchemy.engine.Engine [insertmanyvalues 2223/2250 (ordered; batch not supported)] (741, 2, '2023-04-24 03:07:13.000000', '2020-05-02 17:54:35.000000', 'Seat east development society. Hour official financial ok receive back.\nLoss pick artist daughter stage quickly mother. Save college main. East there list possible new.')
# 2023-09-30 21:09:46,667 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,668 INFO sqlalchemy.engine.Engine [insertmanyvalues 2224/2250 (ordered; batch not supported)] (742, 1, '2021-07-03 16:35:38.000000', '2023-07-20 14:58:38.000000', 'Report hundred former stage near. Cell send himself near baby player myself.\nMajor campaign performance hard anything. Investment play suddenly crime court good manager assume.')
# 2023-09-30 21:09:46,669 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,669 INFO sqlalchemy.engine.Engine [insertmanyvalues 2225/2250 (ordered; batch not supported)] (742, 2, '2021-02-08 14:02:01.000000', '2020-11-22 03:05:37.000000', 'Modern many standard because positive. Most upon seem clear.\nEnjoy civil result organization happy past. Level full mouth national available bank.')
# 2023-09-30 21:09:46,671 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,672 INFO sqlalchemy.engine.Engine [insertmanyvalues 2226/2250 (ordered; batch not supported)] (742, 1, '2023-01-01 12:56:30.000000', '2020-02-11 00:14:50.000000', 'More difficult difficult. Politics shoulder black radio market season. Worry key affect sister actually whose somebody.')
# 2023-09-30 21:09:46,673 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,673 INFO sqlalchemy.engine.Engine [insertmanyvalues 2227/2250 (ordered; batch not supported)] (743, 2, '2020-05-11 01:43:42.000000', '2023-05-20 02:53:23.000000', 'Order state board teach including easy. Teach despite blue experience head direction white.')
# 2023-09-30 21:09:46,674 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,675 INFO sqlalchemy.engine.Engine [insertmanyvalues 2228/2250 (ordered; batch not supported)] (743, 2, '2021-03-18 22:42:50.000000', '2022-11-29 22:00:18.000000', 'Whom practice number ever maybe. End cover wear lay fill. Role heavy hope fall choice. Reduce feel learn especially reduce young.\nManage yeah send him add.')
# 2023-09-30 21:09:46,676 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,677 INFO sqlalchemy.engine.Engine [insertmanyvalues 2229/2250 (ordered; batch not supported)] (743, 3, '2020-03-15 23:11:55.000000', '2023-01-28 19:43:47.000000', 'Shoulder decide out expect fall new. Wear program mention place. Job agency perhaps rise.\nChoose network could most suggest.')
# 2023-09-30 21:09:46,678 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,679 INFO sqlalchemy.engine.Engine [insertmanyvalues 2230/2250 (ordered; batch not supported)] (744, 3, '2022-11-25 00:31:44.000000', '2020-07-27 14:00:01.000000', 'However job old help time when from. Science option wife mean wind.\nChild into per realize collection manager boy should. Power here about suddenly story.')
# 2023-09-30 21:09:46,679 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,680 INFO sqlalchemy.engine.Engine [insertmanyvalues 2231/2250 (ordered; batch not supported)] (744, 1, '2023-03-27 17:06:17.000000', '2023-06-23 16:16:04.000000', 'Politics gas toward ten. Generation should his tree own official. Manager over month.')
# 2023-09-30 21:09:46,681 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,681 INFO sqlalchemy.engine.Engine [insertmanyvalues 2232/2250 (ordered; batch not supported)] (744, 2, '2020-03-15 12:04:58.000000', '2022-11-11 17:46:20.000000', 'Power where follow dog. Natural do it include where red.\nBeat raise forget modern leader stop. Chair opportunity try yard material family similar.')
# 2023-09-30 21:09:46,682 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,683 INFO sqlalchemy.engine.Engine [insertmanyvalues 2233/2250 (ordered; batch not supported)] (745, 2, '2021-08-11 03:21:26.000000', '2022-03-22 13:10:56.000000', 'Stuff head bed become.\nThem themselves sure level. Run world front require member. Try herself feel prepare mind price run assume.')
# 2023-09-30 21:09:46,684 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,685 INFO sqlalchemy.engine.Engine [insertmanyvalues 2234/2250 (ordered; batch not supported)] (745, 1, '2020-10-23 15:36:21.000000', '2021-09-29 10:03:03.000000', 'Term event necessary. Today tell avoid everybody majority lose. My page open way adult compare.')
# 2023-09-30 21:09:46,687 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,688 INFO sqlalchemy.engine.Engine [insertmanyvalues 2235/2250 (ordered; batch not supported)] (745, 1, '2023-01-30 22:32:03.000000', '2023-05-29 17:17:12.000000', 'Writer black eat also. Open score lose statement. Out huge art include blood.\nSocial reality military way learn recognize. Thank hundred early others drive. Picture involve across most.')
# 2023-09-30 21:09:46,689 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,690 INFO sqlalchemy.engine.Engine [insertmanyvalues 2236/2250 (ordered; batch not supported)] (746, 1, '2021-09-14 02:19:50.000000', '2020-09-23 11:05:19.000000', 'Agreement perform outside evidence late cause southern exactly. Team who pressure guy able technology ball.\nKnowledge mention job board. Score gun field tough attention alone character.')
# 2023-09-30 21:09:46,692 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,693 INFO sqlalchemy.engine.Engine [insertmanyvalues 2237/2250 (ordered; batch not supported)] (746, 3, '2022-12-09 13:29:13.000000', '2023-01-15 01:08:17.000000', 'Leader wish fear election protect building always. Road organization determine know million politics time country.\nAway side lot avoid less. Address since bill indeed. Customer both for detail coach.')
# 2023-09-30 21:09:46,693 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,695 INFO sqlalchemy.engine.Engine [insertmanyvalues 2238/2250 (ordered; batch not supported)] (746, 1, '2020-03-06 01:56:32.000000', '2022-12-08 15:40:26.000000', 'Scientist Republican wife however difficult environment. Still hit vote hour soon drug. Food that right true instead class minute.')
# 2023-09-30 21:09:46,696 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,697 INFO sqlalchemy.engine.Engine [insertmanyvalues 2239/2250 (ordered; batch not supported)] (747, 1, '2023-08-01 13:10:19.000000', '2022-07-29 02:34:04.000000', 'Sport plant such economic benefit thus machine. Several own father three think western.\nBy oil then have fly often. Budget rate artist specific. Important resource pull travel country share.')
# 2023-09-30 21:09:46,697 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,698 INFO sqlalchemy.engine.Engine [insertmanyvalues 2240/2250 (ordered; batch not supported)] (747, 1, '2023-04-23 16:41:00.000000', '2020-10-23 01:53:38.000000', 'Evidence agreement book although boy. And treat tax message before myself understand.\nMatter lose nice. Enter none purpose rock place. Teach material authority standard city from.')
# 2023-09-30 21:09:46,698 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,699 INFO sqlalchemy.engine.Engine [insertmanyvalues 2241/2250 (ordered; batch not supported)] (747, 3, '2021-04-09 15:25:04.000000', '2021-07-08 05:43:41.000000', 'Court best staff from.')
# 2023-09-30 21:09:46,699 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,700 INFO sqlalchemy.engine.Engine [insertmanyvalues 2242/2250 (ordered; batch not supported)] (748, 3, '2020-09-01 11:02:03.000000', '2023-07-09 13:01:52.000000', 'Visit discover party the because adult vote concern. Head trip news similar key.\nCommon dog store least note fire speak. Safe check score budget back hand.')
# 2023-09-30 21:09:46,700 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,701 INFO sqlalchemy.engine.Engine [insertmanyvalues 2243/2250 (ordered; batch not supported)] (748, 2, '2020-04-29 13:53:15.000000', '2021-02-20 08:23:31.000000', 'Create see participant visit food move later.\nWind campaign whose term whose. Truth involve century remember. Big itself option do.')
# 2023-09-30 21:09:46,703 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,703 INFO sqlalchemy.engine.Engine [insertmanyvalues 2244/2250 (ordered; batch not supported)] (748, 3, '2023-05-08 23:36:18.000000', '2020-03-18 01:48:22.000000', 'Crime move worry trial scientist out region. Throw without peace western gun think.\nType major middle authority. Truth great kitchen nor. Effect loss analysis beat scientist.')
# 2023-09-30 21:09:46,704 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,705 INFO sqlalchemy.engine.Engine [insertmanyvalues 2245/2250 (ordered; batch not supported)] (749, 1, '2023-08-10 04:41:04.000000', '2023-06-04 16:27:10.000000', 'Everything crime common hope. Administration brother test church.\nYour sort according choice skill idea stuff. Difference marriage Congress firm.')
# 2023-09-30 21:09:46,706 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,706 INFO sqlalchemy.engine.Engine [insertmanyvalues 2246/2250 (ordered; batch not supported)] (749, 1, '2023-09-19 00:57:14.000000', '2023-08-13 01:10:32.000000', 'Individual situation money office scientist enough gun prevent. Finish audience customer film.')
# 2023-09-30 21:09:46,707 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,708 INFO sqlalchemy.engine.Engine [insertmanyvalues 2247/2250 (ordered; batch not supported)] (749, 1, '2022-11-18 23:42:10.000000', '2020-02-18 04:50:08.000000', 'Prove billion provide develop. Since race voice market possible.\nEither data south board charge also past. Pattern stock article put group then. Bank indicate science ball.')
# 2023-09-30 21:09:46,708 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,709 INFO sqlalchemy.engine.Engine [insertmanyvalues 2248/2250 (ordered; batch not supported)] (750, 2, '2023-02-23 09:58:14.000000', '2022-12-25 10:18:05.000000', 'Lawyer alone source big heavy. Others open show month state gun. Hair trip ok church drop administration.\nYard visit behind ago green tend growth. Arrive within according Democrat onto.')
# 2023-09-30 21:09:46,710 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,710 INFO sqlalchemy.engine.Engine [insertmanyvalues 2249/2250 (ordered; batch not supported)] (750, 1, '2022-05-17 19:08:31.000000', '2022-06-26 03:50:58.000000', 'Family find time area Mr my defense. Risk popular cell sell. Player which live project network garden money.\nEspecially authority relationship whose old. Research garden huge.')
# 2023-09-30 21:09:46,711 INFO sqlalchemy.engine.Engine INSERT INTO fact_ticket_lines (ticket_id, technician_id, assignment_date_time, completion_date_time, notes) VALUES (?, ?, ?, ?, ?) RETURNING ticket_line_id
# 2023-09-30 21:09:46,712 INFO sqlalchemy.engine.Engine [insertmanyvalues 2250/2250 (ordered; batch not supported)] (750, 1, '2021-05-19 00:05:48.000000', '2020-06-05 19:39:14.000000', 'Voice fast military family hotel low brother. Risk avoid themselves still foot college.\nReason couple when personal public vote. Of possible teach. Culture throughout he hour. More current turn.')
# 2023-09-30 21:09:46,731 INFO sqlalchemy.engine.Engine COMMIT
# 2023-09-30 21:09:46,761 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-30 21:09:46,763 INFO sqlalchemy.engine.Engine SELECT fact_ticket_lines.ticket_line_id AS fact_ticket_lines_ticket_line_id, fact_ticket_lines.ticket_id AS fact_ticket_lines_ticket_id, fact_ticket_lines.technician_id AS fact_ticket_lines_technician_id, fact_ticket_lines.assignment_date_time AS fact_ticket_lines_assignment_date_time, fact_ticket_lines.completion_date_time AS fact_ticket_lines_completion_date_time, fact_ticket_lines.notes AS fact_ticket_lines_notes
# FROM fact_ticket_lines
# 2023-09-30 21:09:46,764 INFO sqlalchemy.engine.Engine [generated in 0.00130s] ()

# %%
print(f'date_time_this_decade: {fake.date_time_this_decade()}')
print(f'word: {fake.word()}')
print(f'sentence: {fake.sentence()}')
print(f'text: {fake.text()}')
print(f'first_name: {fake.first_name()}')
print(f'last_name: {fake.last_name()}')
print(f'phone_number: {fake.phone_number()}')
print(f'email: {fake.email()}')
print(f'job: {fake.job()}')
print(f'company: {fake.company()}')
print(f'company_email: {fake.company_email()}')
print(f'state_abbr: {fake.state_abbr()}')
print(f'city: {fake.city()}')
print(f'zipcode: {fake.zipcode()}')
print(f'street_address: {fake.street_address()}')
print(f'bs: {fake.bs()}')





#Tickets:
#ticket_category
#open_date_time
#close_date_time
#status
#description
#subject
#
#Ticket Lines:
#assignment_date_time
#completion_date_time
#notes
#
#Users
#last_name
#first_name
#phone_number
#email_address
#title
#
#Departments
#name
#phone_number
#
#Organizations
#name
#phone_number
#email_address
#state
#city
#zip_code
#street_address
#
#
#
# Out:
# date_time_this_decade: 2021-10-11 15:42:55
# word: like
# sentence: They task audience trouble power performance major.
# text: Vote create population air. Treat range large after see public race.
# Just force effect it and now letter either. Others writer thousand piece single already.
# first_name: Jose
# last_name: Morse
# phone_number: +1-676-898-1361
# email: owilson@example.org
# job: Bookseller
# company: David-Stephens
# company_email: uyoung@richardson.info
# state_abbr: SD
# city: Jonathanland
# zipcode: 39121
# street_address: 597 Cynthia Villages
# bs: empower next-generation vortals

# %%
import pandas as pd

date_time_pre=fake.date_time_this_decade()

hours_taken = fake.random_int(min=0, max=4)
minutes_taken = fake.random_int(min=0, max=59)

date_time_post = date_time_pre + pd.DateOffset(hours=hours_taken, minutes=minutes_taken)


print(date_time_pre)
print(hours_taken)

print(minutes_taken)
print(date_time_post)
# Out:
# 2022-08-07 09:54:28
# 1
# 23
# 2022-08-07 11:17:28

# %%
department_names = [
    'Department 1'
    , 'Department 2'
    , 'Department 3'
    , 'Department 4'
    , 'Department 5'
]

departments = session.query(Department).all()

for department in departments:
    selected_department = fake.random_int(min=0, max=len(department_names)-1)
    department.name = department_names[selected_department]
session.commit()

#123456789
# Out:
# 2023-09-30 21:55:46,563 INFO sqlalchemy.engine.Engine UPDATE dim_departments SET name=? WHERE dim_departments.department_id = ?
# 2023-09-30 21:55:46,565 INFO sqlalchemy.engine.Engine [cached since 436.7s ago] [('Department 2', 3), ('Department 1', 5), ('Department 2', 6), ('Department 1', 7), ('Department 3', 8), ('Department 2', 9), ('Department 5', 10)]
# 2023-09-30 21:55:46,572 INFO sqlalchemy.engine.Engine SELECT dim_departments.department_id AS dim_departments_department_id, dim_departments.organization_id AS dim_departments_organization_id, dim_departments.name AS dim_departments_name, dim_departments.phone_number AS dim_departments_phone_number, dim_departments.email_address AS dim_departments_email_address
# FROM dim_departments
# 2023-09-30 21:55:46,574 INFO sqlalchemy.engine.Engine [cached since 2769s ago] ()
# 2023-09-30 21:55:46,577 INFO sqlalchemy.engine.Engine UPDATE dim_departments SET name=? WHERE dim_departments.department_id = ?
# 2023-09-30 21:55:46,580 INFO sqlalchemy.engine.Engine [cached since 436.7s ago] [('Department 3', 1), ('Department 1', 2), ('Department 1', 3), ('Department 2', 4), ('Department 5', 5), ('Department 5', 6), ('Department 4', 7), ('Department 5', 8)  ... displaying 10 of 15 total bound parameter sets ...  ('Department 3', 14), ('Department 4', 15)]
# 2023-09-30 21:55:46,583 INFO sqlalchemy.engine.Engine COMMIT
