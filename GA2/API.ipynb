# %% [markdown]
# ### Install the necessary packages:

# %%
import G1_common_tools as tools
tools.install_required_packages()
# Out:
# sqlalchemy_utils is already installed.
# Faker not found. Installing...
# Faker has been installed.
# fastapi[all] not found. Installing...
# fastapi[all] has been installed.

# %% [markdown]
# ### Set up the base of the API:

# %%
from fastapi import FastAPI
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey,func
from sqlalchemy.orm import sessionmaker, relationship, declarative_base, joinedload
from datetime import timedelta
import table_structures as t

# Database setup
DATABASE_URL = "sqlite:///it_ticketing_system.db"
Base = declarative_base()
engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)

# FastAPI setup
app = FastAPI(
    title="IT Ticketing System API",
    description="API for Group 1's IT Ticketing System",
    version="0.1",
)

# %% [markdown]
# ### API Definitions:

# %%
@app.get("/Technicians/")
def read_technician_names():
    '''
    Returns the first and last names of all the technicians
    '''
    db = SessionLocal()
    query = db.query(t.User).join(t.Technician).all()

    technicians = []
    for row in query:
        technician = row.first_name + ' ' + row.last_name
        technicians.append(technician)
    db.close()
    return technicians

@app.get("/Technicians/AvgTicketTimes/")
def read_technician_avg_ticket_times():
    '''
    TODO: Insert tooltip documentation here
    '''
    db = SessionLocal()
    query = db.query(t.Technician).join(t.TicketLine).join(t.User)
    query.all()
    technicians = []
    for row in query:
        ticket_durations = []
        for x in row.ticket_lines:
            interval = x.completion_date_time - x.assignment_date_time
            ticket_durations.append(interval)
        total_seconds = sum(interval.total_seconds() for interval in ticket_durations)
        average_seconds = total_seconds / len(ticket_durations) if ticket_durations else 0
        average_interval = timedelta(seconds=average_seconds)
        technician = row.user.first_name + ' ' + row.user.last_name + ' - Average Ticket Time: ' + str(average_interval)
        technicians.append(technician)
    db.close()
    return technicians


@app.get("/Users/TicketCounts/")
def read_user_ticket_counts(user_id=None):
    '''
    TODO: Insert tooltip documentation here
    '''
    db = SessionLocal()
    query = db.query(t.User).join(t.Ticket)
    user_data = []
    if not user_id:
        users = query.all()
    else:
        users = query.filter(t.User.user_id == user_id).all()

    for row in users:
        ticket_count = len(row.tickets)
        user = row.first_name + ' ' + row.last_name + ' Ticket Count: ' + str(ticket_count)
        user_data.append(user)

    db.close()
    return user_data


@app.get("/Departments/AvgResolutionTimes")
def read_department_avg_resolution_time():
    '''
    TODO: Retrieve and print the average resolution times for each department.
    '''
    db = SessionLocal()
    query = db.query(t.Department.name, func.avg(t.Ticket.close_date_time - t.Ticket.open_date_time).label('avg_resolution_time_minutes'))\
    .join(t.Ticket, t.Department.department_id == t.Ticket.department_id)\
    .group_by(t.Department.name)
    
    results = query.all()

    departments = []
    for department_name, avg_resolution_time_minutes in results:
        departments.append(department_name + ' ' + str(avg_resolution_time_minutes))

    db.close()
    return departments

@app.get("/Technicians/TicketsInfo")
def read_technician_ticketinfo():
    '''
    TODO: Retrieve and print ticket information for each technician based on technician ID.
    '''
    db = SessionLocal()

    desired_technician_id = 1

    query = db.query(t.Ticket.ticket_id, t.Ticket.subject, t.Ticket.open_date_time, t.Ticket.close_date_time)\
    .join(t.TicketLine, t.Ticket.ticket_id == t.TicketLine.ticket_id)\
    .filter(t.TicketLine.technician_id == desired_technician_id)
    
    results = query.all()

    technicianticket = []
    for ticket_id, subject, open_date_time, close_date_time in results:
        technicianticket.append(' Ticket ID: ' + str(ticket_id) + ' Subject: ' + subject + ' Open Date: ' + str(open_date_time) + ' Closed Date ' + str(close_date_time))

    db.close()
    return technicianticket

@app.get("/Organizations/TicketCounts")
def read_organizations_tickets_count():
    '''
    TODO: Retrieve and print ticket counts for each organization.
    '''
    db = SessionLocal()

    query = db.query(t.User).join(t.Organization).group_by(t.Organization.name)

    results = query.all()

    organizationticket = []
    for row in results:
        organizationticket.append(row.organization.name + ' ' + str(len(row.tickets)))

    db.close()
    return organizationticket

# %% [markdown]
# ### API Calls

# %%
# print(read_technician_names())
# print(read_technician_avg_ticket_times())
# print(read_user_ticket_counts())
# print(read_user_ticket_counts(1))
print(read_department_avg_resolution_time())
print(read_technician_ticketinfo())
print(read_organizations_tickets_count())
# Out:
# ['Administration 0.03571428571428571', 'Human Resources 0.14432989690721648', 'IT Support -0.030303030303030304', 'Marketing 0.15', 'Public Relations 0.06818181818181818', 'Sales 0.07692307692307693', 'Supply Chain -0.1724137931034483']
# [' Ticket ID: 4 Subject: North out message list. Open Date: 2020-07-22 18:16:44 Closed Date 2022-04-16 03:16:27', ' Ticket ID: 5 Subject: Even sometimes reach policy. Open Date: 2021-08-11 21:53:14 Closed Date 2022-06-07 19:50:26', ' Ticket ID: 6 Subject: Little discover pressure. Open Date: 2020-07-03 12:10:19 Closed Date 2020-05-06 21:58:13', ' Ticket ID: 9 Subject: Letter stay city actually each another. Open Date: 2021-03-08 13:22:06 Closed Date 2023-01-14 00:23:51', ' Ticket ID: 12 Subject: Resource day your study hear data. Open Date: 2020-08-06 22:36:36 Closed Date 2021-08-13 12:14:58', ' Ticket ID: 12 Subject: Resource day your study hear data. Open Date: 2020-08-06 22:36:36 Closed Date 2021-08-13 12:14:58', ' Ticket ID: 14 Subject: Best require under finish you. Open Date: 2020-12-20 12:07:41 Closed Date 2020-02-02 01:56:44', ' Ticket ID: 15 Subject: Program entire maintain seat would brother. Open Date: 2021-09-15 01:18:46 Closed Date 2023-03-16 04:00:20', ' Ticket ID: 15 Subject: Program entire maintain seat would brother. Open Date: 2021-09-15 01:18:46 Closed Date 2023-03-16 04:00:20', ' Ticket ID: 16 Subject: Between reflect across center either thousand training. Open Date: 2021-01-20 05:53:25 Closed Date 2021-09-25 02:10:36', ' Ticket ID: 16 Subject: Between reflect across center either thousand training. Open Date: 2021-01-20 05:53:25 Closed Date 2021-09-25 02:10:36', ' Ticket ID: 17 Subject: Surface top staff another likely describe skill. Open Date: 2023-09-01 14:26:04 Closed Date 2021-10-27 17:43:07', ' Ticket ID: 20 Subject: Various view collection professional energy us. Open Date: 2022-05-10 23:36:09 Closed Date 2022-09-19 04:31:44', ' Ticket ID: 22 Subject: Site fire sound your. Open Date: 2021-11-30 06:02:14 Closed Date 2023-02-17 09:33:46', ' Ticket ID: 24 Subject: Establish bed increase without mind. Open Date: 2022-12-05 10:18:23 Closed Date 2021-03-17 20:54:43', ' Ticket ID: 25 Subject: Side begin security current. Open Date: 2022-07-01 11:18:36 Closed Date 2023-03-11 23:40:09', ' Ticket ID: 25 Subject: Side begin security current. Open Date: 2022-07-01 11:18:36 Closed Date 2023-03-11 23:40:09', ' Ticket ID: 25 Subject: Side begin security current. Open Date: 2022-07-01 11:18:36 Closed Date 2023-03-11 23:40:09', ' Ticket ID: 26 Subject: People much past film when treatment matter. Open Date: 2022-08-05 20:48:16 Closed Date 2021-12-22 08:02:51', ' Ticket ID: 28 Subject: Rate little nature need maybe current everything. Open Date: 2022-12-27 18:54:53 Closed Date 2020-09-27 12:25:42', ' Ticket ID: 29 Subject: Then he their here good lay. Open Date: 2023-06-25 10:49:51 Closed Date 2021-04-14 02:01:38', ' Ticket ID: 30 Subject: Staff way identify speak mind. Open Date: 2020-01-25 09:31:17 Closed Date 2023-01-24 20:09:45', ' Ticket ID: 31 Subject: While describe write even. Open Date: 2021-03-06 15:42:53 Closed Date 2022-10-23 20:24:36', ' Ticket ID: 32 Subject: Short guess perhaps key number appear term. Open Date: 2023-05-10 09:53:50 Closed Date 2022-03-02 20:10:40', ' Ticket ID: 32 Subject: Short guess perhaps key number appear term. Open Date: 2023-05-10 09:53:50 Closed Date 2022-03-02 20:10:40', ' Ticket ID: 34 Subject: Onto interesting interesting forget. Open Date: 2021-02-05 05:19:14 Closed Date 2020-03-25 18:47:30', ' Ticket ID: 34 Subject: Onto interesting interesting forget. Open Date: 2021-02-05 05:19:14 Closed Date 2020-03-25 18:47:30', ' Ticket ID: 35 Subject: Hope research strong reality citizen outside conference. Open Date: 2023-02-24 07:54:01 Closed Date 2021-10-17 09:18:32', ' Ticket ID: 36 Subject: Expert say while meet away simple officer. Open Date: 2020-07-15 15:43:37 Closed Date 2023-08-22 03:42:31', ' Ticket ID: 36 Subject: Expert say while meet away simple officer. Open Date: 2020-07-15 15:43:37 Closed Date 2023-08-22 03:42:31', ' Ticket ID: 37 Subject: Son TV floor opportunity traditional. Open Date: 2022-12-16 17:17:55 Closed Date 2022-07-05 17:21:08', ' Ticket ID: 38 Subject:  ...
# ['Acme Corporation 0', 'Finance World Group 4', 'Marketing Innovators 1', 'Tech Solutions Inc. 3']
